# %% [markdown]
# ## Train Neural Translation Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pickle import load
from numpy import array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.models import load_model
from numpy import argmax
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# %%
# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# %%
# load datasets
loc = 'drive/MyDrive/nmt_test/'

# load datasets
dataset = load_clean_sentences(loc + 'english-nepali-both.pkl')
train = load_clean_sentences(loc + 'english-nepali-train.pkl')
test = load_clean_sentences(loc + 'english-nepali-test.pkl')

# %%
# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# %%
# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# %%
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare nepali tokenizer
nep_tokenizer = create_tokenizer(dataset[:, 1])
nep_vocab_size = len(nep_tokenizer.word_index) + 1
nep_length = max_length(dataset[:, 1])
print('Nepali Vocabulary Size: %d' % nep_vocab_size)
print('Nepali Max Length: %d' % (nep_length))
# Out:
# English Vocabulary Size: 9285
# English Max Length: 20
# Nepali Vocabulary Size: 17085
# Nepali Max Length: 20

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# %%
# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# %%
# prepare training data
trainX = encode_sequences(nep_tokenizer, nep_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(nep_tokenizer, nep_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)
train[1]
# Out:
# array(['epidemiological data revealed retrospectively that the index case of sars had a contact history with game animals',
#        'महामारी सम्बन्धी डाटाले पूर्वव्यापी ढङ्गमा sars को सूचक केसमा खेल पशुहरूसँग सम्पर्क इतिहास भएको कुरा खुलासा गर्\u200dयो।'],
#       dtype='<U1491')

# %%
# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
# 	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(Embedding(src_vocab, 128, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# define model
model = define_model(nep_vocab_size, eng_vocab_size, nep_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)

# %%
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=500, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/500
# 83/83 - 20s - loss: 5.5600 - val_loss: 4.9666
#
# Epoch 00001: val_loss improved from inf to 4.96661, saving model to model.h5
# Epoch 2/500
# 83/83 - 6s - loss: 4.7489 - val_loss: 4.8276
#
# Epoch 00002: val_loss improved from 4.96661 to 4.82763, saving model to model.h5
# Epoch 3/500
# 83/83 - 6s - loss: 4.6165 - val_loss: 4.7543
#
# Epoch 00003: val_loss improved from 4.82763 to 4.75429, saving model to model.h5
# Epoch 4/500
# 83/83 - 6s - loss: 4.6213 - val_loss: 4.7638
#
# Epoch 00004: val_loss did not improve from 4.75429
# Epoch 5/500
# 83/83 - 6s - loss: 4.4544 - val_loss: 4.6634
#
# Epoch 00005: val_loss improved from 4.75429 to 4.66340, saving model to model.h5
# Epoch 6/500
# 83/83 - 6s - loss: 4.3055 - val_loss: 4.6791
#
# Epoch 00006: val_loss did not improve from 4.66340
# Epoch 7/500
# 83/83 - 6s - loss: 4.2549 - val_loss: 4.6772
#
# Epoch 00007: val_loss did not improve from 4.66340
# Epoch 8/500
# 83/83 - 6s - loss: 4.2172 - val_loss: 4.6796
#
# Epoch 00008: val_loss did not improve from 4.66340
# Epoch 9/500
# 83/83 - 6s - loss: 4.2008 - val_loss: 4.7110
#
# Epoch 00009: val_loss did not improve from 4.66340
# Epoch 10/500
# 83/83 - 6s - loss: 4.1887 - val_loss: 4.6864
#
# Epoch 00010: val_loss did not improve from 4.66340
# Epoch 11/500
# 83/83 - 6s - loss: 4.1597 - val_loss: 4.7131
#
# Epoch 00011: val_loss did not improve from 4.66340
# Epoch 12/500
# 83/83 - 6s - loss: 4.1389 - val_loss: 4.7125
#
# Epoch 00012: val_loss did not improve from 4.66340
# Epoch 13/500
# 83/83 - 6s - loss: 4.1282 - val_loss: 4.7125
#
# Epoch 00013: val_loss did not improve from 4.66340
# Epoch 14/500
# 83/83 - 6s - loss: 4.1171 - val_loss: 4.7146
#
# Epoch 00014: val_loss did not improve from 4.66340
# Epoch 15/500
# 83/83 - 6s - loss: 4.1075 - val_loss: 4.7345
#
# Epoch 00015: val_loss did not improve from 4.66340
# Epoch 16/500
# 83/83 - 6s - loss: 4.0917 - val_loss: 4.7325
#
# Epoch 00016: val_loss did not improve from 4.66340
# Epoch 17/500
# 83/83 - 6s - loss: 4.0894 - val_loss: 4.7426
#
# Epoch 00017: val_loss did not improve from 4.66340
# Epoch 18/500
# 83/83 - 6s - loss: 4.0779 - val_loss: 4.7434
#
# Epoch 00018: val_loss did not improve from 4.66340
# Epoch 19/500
# 83/83 - 6s - loss: 4.0675 - val_loss: 4.7752
#
# Epoch 00019: val_loss did not improve from 4.66340
# Epoch 20/500
# 83/83 - 6s - loss: 4.0675 - val_loss: 4.7628
#
# Epoch 00020: val_loss did not improve from 4.66340
# Epoch 21/500
# 83/83 - 6s - loss: 4.0532 - val_loss: 4.7606
#
# Epoch 00021: val_loss did not improve from 4.66340
# Epoch 22/500
# 83/83 - 6s - loss: 4.0447 - val_loss: 4.7794
#
# Epoch 00022: val_loss did not improve from 4.66340
# Epoch 23/500
# 83/83 - 6s - loss: 4.0331 - val_loss: 4.7850
#
# Epoch 00023: val_loss did not improve from 4.66340
# Epoch 24/500
# 83/83 - 6s - loss: 4.0214 - val_loss: 4.7914
#
# Epoch 00024: val_loss did not improve from 4.66340
# Epoch 25/500
# 83/83 - 6s - loss: 4.0109 - val_loss: 4.8008
#
# Epoch 00025: val_loss did not improve from 4.66340
# Epoch 26/500
# 83/83 - 6s - loss: 3.9936 - val_loss: 4.7967
#
# Epoch 00026: val_loss did not improve from 4.66340
# Epoch 27/500
# 83/83 - 6s - loss: 3.9763 - val_loss: 4.8162
#
# Epoch 00027: val_loss did not improve from 4.66340
# Epoch 28/500
# 83/83 - 6s - loss: 3.9635 - val_loss: 4.8049
#
# Epoch 00028: val_loss did not improve from 4.66340
# Epoch 29/500
# 83/83 - 6s - loss: 3.9464 - val_loss: 4.7823
#
# Epoch 00029: val_loss did not improve from 4.66340
# Epoch 30/500
# 83/83 - 6s - loss: 3.9251 - val_loss: 4.7808
#
# Epoch 00030: val_loss did not improve from 4.66340
# Epoch 31/500
# 83/83 - 6s - loss: 3.9019 - val_loss: 4.7789
#
# Epoch 00031: val_loss did not improve from 4.66340
# Epoch 32/500
# 83/83 - 6s - loss: 3.8853 - val_loss: 4.7711
#
# Epoch 00032: val_loss did not improve from 4.66340
# Epoch 33/500
# 83/83 - 6s - loss: 3.8657 - val_loss: 4.7758
#
# Epoch 00033: val_loss did not improve from 4.66340
# Epoch 34/500
# 83/83 - 6s - loss: 3.8588 - val_loss: 4.7946
#
# Epoch 00034: val_loss did not improve from 4.66340
# Epoch 35/500
# 83/83 - 6s - loss: 3.8453 - val_loss: 4.8002
#
# Epoch 00035: val_loss did not improve from 4.66340
# Epoch 36/500
# 83/83 - 6s - loss: 3.8265 - val_loss: 4.7979
#
# Epoch 00036: val_loss did not improve from 4.66340
# Epoch 37/500
# 83/83 - 6s - loss: 3.8278 - val_loss: 4.7896
#
# Epoch 00037: val_loss did not improve from 4.66340
# Epoch 38/500
# 83/83 - 6s - loss: 3.8158 - val_loss: 4.7804
#
# Epoch 00038: val_loss did not improve from 4.66340
# Epoch 39/500
# 83/83 - 6s - loss: 3.7924 - val_loss: 4.8084
#
# Epoch 00039: val_loss did not improve from 4.66340
# Epoch 40/500
# 83/83 - 6s - loss: 3.7895 - val_loss: 4.7973
#
# Epoch 00040: val_loss did not improve from 4.66340
# Epoch 41/500
# 83/83 - 6s - loss: 3.7744 - val_loss: 4.8181
#
# Epoch 00041: val_loss did not improve from 4.66340
# Epoch 42/500
# 83/83 - 6s - loss: 3.7590 - val_loss: 4.8297
#
# Epoch 00042: val_loss did not improve from 4.66340
# Epoch 43/500
# 83/83 - 6s - loss: 3.7525 - val_loss: 4.8238
#
# Epoch 00043: val_loss did not improve from 4.66340
# Epoch 44/500
# 83/83 - 6s - loss: 3.7355 - val_loss: 4.8243
#
# Epoch 00044: val_loss did not improve from 4.66340
# Epoch 45/500
# 83/83 - 6s - loss: 3.7228 - val_loss: 4.8374
#
# Epoch 00045: val_loss did not improve from 4.66340
# Epoch 46/500
# 83/83 - 6s - loss: 3.7087 - val_loss: 4.8372
#
# Epoch 00046: val_loss did not improve from 4.66340
# Epoch 47/500
# 83/83 - 6s - loss: 3.6948 - val_loss: 4.8375
#
# Epoch 00047: val_loss did not improve from 4.66340
# Epoch 48/500
# 83/83 - 6s - loss: 3.6798 - val_loss: 4.8762
#
# Epoch 00048: val_loss did not improve from 4.66340
# Epoch 49/500
# 83/83 - 6s - loss: 3.6942 - val_loss: 4.8647
#
# Epoch 00049: val_loss did not improve from 4.66340
# Epoch 50/500
# 83/83 - 6s - loss: 3.6924 - val_loss: 4.8405
#
# Epoch 00050: val_loss did not improve from 4.66340
# Epoch 51/500
# 83/83 - 6s - loss: 3.6616 - val_loss: 4.8620
#
# Epoch 00051: val_loss did not improve from 4.66340
# Epoch 52/500
# 83/83 - 6s - loss: 3.6427 - val_loss: 4.8810
#
# Epoch 00052: val_loss did not improve from 4.66340
# Epoch 53/500
# 83/83 - 6s - loss: 3.6279 - val_loss: 4.8982
#
# Epoch 00053: val_loss did not improve from 4.66340
# Epoch 54/500
# 83/83 - 6s - loss: 3.6059 - val_loss: 4.8832
#
# Epoch 00054: val_loss did not improve from 4.66340
# Epoch 55/500
# 83/83 - 6s - loss: 3.5877 - val_loss: 4.8908
#
# Epoch 00055: val_loss did not improve from 4.66340
# Epoch 56/500
# 83/83 - 6s - loss: 3.5748 - val_loss: 4.9253
#
# Epoch 00056: val_loss did not improve from 4.66340
# Epoch 57/500
# 83/83 - 6s - loss: 3.5547 - val_loss: 4.9332
#
# Epoch 00057: val_loss did not improve from 4.66340
# Epoch 58/500
# 83/83 - 6s - loss: 3.5449 - val_loss: 4.9075
#
# Epoch 00058: val_loss did not improve from 4.66340
# Epoch 59/500
# 83/83 - 6s - loss: 3.5384 - val_loss: 4.9042
#
# Epoch 00059: val_loss did not improve from 4.66340
# Epoch 60/500
# 83/83 - 6s - loss: 3.5188 - val_loss: 4.9311
#
# Epoch 00060: val_loss did not improve from 4.66340
# Epoch 61/500
# 83/83 - 6s - loss: 3.4927 - val_loss: 4.9402
#
# Epoch 00061: val_loss did not improve from 4.66340
# Epoch 62/500
# 83/83 - 6s - loss: 3.4671 - val_loss: 4.9462
#
# Epoch 00062: val_loss did not improve from 4.66340
# Epoch 63/500
# 83/83 - 6s - loss: 3.4534 - val_loss: 4.9328
#
# Epoch 00063: val_loss did not improve from 4.66340
# Epoch 64/500
# 83/83 - 6s - loss: 3.4402 - val_loss: 4.9673
#
# Epoch 00064: val_loss did not improve from 4.66340
# Epoch 65/500
# 83/83 - 6s - loss: 3.4278 - val_loss: 4.9612
#
# Epoch 00065: val_loss did not improve from 4.66340
# Epoch 66/500
# 83/83 - 6s - loss: 3.4012 - val_loss: 4.9354
#
# Epoch 00066: val_loss did not improve from 4.66340
# Epoch 67/500
# 83/83 - 6s - loss: 3.3853 - val_loss: 4.9645
#
# Epoch 00067: val_loss did not improve from 4.66340
# Epoch 68/500
# 83/83 - 6s - loss: 3.3771 - val_loss: 5.0024
#
# Epoch 00068: val_loss did not improve from 4.66340
# Epoch 69/500
# 83/83 - 6s - loss: 3.3495 - val_loss: 4.9870
#
# Epoch 00069: val_loss did not improve from 4.66340
# Epoch 70/500
# 83/83 - 6s - loss: 3.3300 - val_loss: 4.9727
#
# Epoch 00070: val_loss did not improve from 4.66340
# Epoch 71/500
# 83/83 - 6s - loss: 3.3053 - val_loss: 5.0029
#
# Epoch 00071: val_loss did not improve from 4.66340
# Epoch 72/500
# 83/83 - 6s - loss: 3.2839 - val_loss: 5.0140
#
# Epoch 00072: val_loss did not improve from 4.66340
# Epoch 73/500
# 83/83 - 6s - loss: 3.2694 - val_loss: 5.0194
#
# Epoch 00073: val_loss did not improve from 4.66340
# Epoch 74/500
# 83/83 - 6s - loss: 3.2499 - val_loss: 5.0232
#
# Epoch 00074: val_loss did not improve from 4.66340
# Epoch 75/500
# 83/83 - 6s - loss: 3.2337 - val_loss: 5.0144
#
# Epoch 00075: val_loss did not improve from 4.66340
# Epoch 76/500
# 83/83 - 6s - loss: 3.2162 - val_loss: 5.0397
#
# Epoch 00076: val_loss did not improve from 4.66340
# Epoch 77/500
# 83/83 - 6s - loss: 3.1978 - val_loss: 5.0580
#
# Epoch 00077: val_loss did not improve from 4.66340
# Epoch 78/500
# 83/83 - 6s - loss: 3.1718 - val_loss: 5.0506
#
# Epoch 00078: val_loss did not improve from 4.66340
# Epoch 79/500
# 83/83 - 6s - loss: 3.1520 - val_loss: 5.0381
#
# Epoch 00079: val_loss did not improve from 4.66340
# Epoch 80/500
# 83/83 - 6s - loss: 3.1423 - val_loss: 5.0780
#
# Epoch 00080: val_loss did not improve from 4.66340
# Epoch 81/500
# 83/83 - 6s - loss: 3.1435 - val_loss: 5.0552
#
# Epoch 00081: val_loss did not improve from 4.66340
# Epoch 82/500
# 83/83 - 6s - loss: 3.1105 - val_loss: 5.0547
#
# Epoch 00082: val_loss did not improve from 4.66340
# Epoch 83/500
# 83/83 - 6s - loss: 3.0824 - val_loss: 5.0856
#
# Epoch 00083: val_loss did not improve from 4.66340
# Epoch 84/500
# 83/83 - 6s - loss: 3.0773 - val_loss: 5.0776
#
# Epoch 00084: val_loss did not improve from 4.66340
# Epoch 85/500
# 83/83 - 6s - loss: 3.0555 - val_loss: 5.0768
#
# Epoch 00085: val_loss did not improve from 4.66340
# Epoch 86/500
# 83/83 - 6s - loss: 3.0252 - val_loss: 5.0942
#
# Epoch 00086: val_loss did not improve from 4.66340
# Epoch 87/500
# 83/83 - 6s - loss: 3.0011 - val_loss: 5.0774
#
# Epoch 00087: val_loss did not improve from 4.66340
# Epoch 88/500
# 83/83 - 6s - loss: 2.9838 - val_loss: 5.0929
#
# Epoch 00088: val_loss did not improve from 4.66340
# Epoch 89/500
# 83/83 - 6s - loss: 2.9691 - val_loss: 5.0724
#
# Epoch 00089: val_loss did not improve from 4.66340
# Epoch 90/500
# 83/83 - 6s - loss: 2.9555 - val_loss: 5.0831
#
# Epoch 00090: val_loss did not improve from 4.66340
# Epoch 91/500
# 83/83 - 6s - loss: 2.9309 - val_loss: 5.1180
#
# Epoch 00091: val_loss did not improve from 4.66340
# Epoch 92/500
# 83/83 - 6s - loss: 2.9233 - val_loss: 5.1021
#
# Epoch 00092: val_loss did not improve from 4.66340
# Epoch 93/500
# 83/83 - 6s - loss: 2.9127 - val_loss: 5.1552
#
# Epoch 00093: val_loss did not improve from 4.66340
# Epoch 94/500
# 83/83 - 6s - loss: 2.8932 - val_loss: 5.1505
#
# Epoch 00094: val_loss did not improve from 4.66340
# Epoch 95/500
# 83/83 - 6s - loss: 2.8669 - val_loss: 5.1523
#
# Epoch 00095: val_loss did not improve from 4.66340
# Epoch 96/500
# 83/83 - 6s - loss: 2.8619 - val_loss: 5.1621
#
# Epoch 00096: val_loss did not improve from 4.66340
# Epoch 97/500
# 83/83 - 6s - loss: 2.8362 - val_loss: 5.1667
#
# Epoch 00097: val_loss did not improve from 4.66340
# Epoch 98/500
# 83/83 - 6s - loss: 2.8089 - val_loss: 5.1709
#
# Epoch 00098: val_loss did not improve from 4.66340
# Epoch 99/500
# 83/83 - 6s - loss: 2.7919 - val_loss: 5.1407
#
# Epoch 00099: val_loss did not improve from 4.66340
# Epoch 100/500
# 83/83 - 6s - loss: 2.7745 - val_loss: 5.1671
#
# Epoch 00100: val_loss did not improve from 4.66340
# Epoch 101/500
# 83/83 - 6s - loss: 2.7480 - val_loss: 5.1638
#
# Epoch 00101: val_loss did not improve from 4.66340
# Epoch 102/500
# 83/83 - 6s - loss: 2.7246 - val_loss: 5.1647
#
# Epoch 00102: val_loss did not improve from 4.66340
# Epoch 103/500
# 83/83 - 6s - loss: 2.7013 - val_loss: 5.1543
#
# Epoch 00103: val_loss did not improve from 4.66340
# Epoch 104/500
# 83/83 - 6s - loss: 2.6825 - val_loss: 5.1905
#
# Epoch 00104: val_loss did not improve from 4.66340
# Epoch 105/500
# 83/83 - 6s - loss: 2.6758 - val_loss: 5.2052
#
# Epoch 00105: val_loss did not improve from 4.66340
# Epoch 106/500
# 83/83 - 6s - loss: 2.7637 - val_loss: 5.1917
#
# Epoch 00106: val_loss did not improve from 4.66340
# Epoch 107/500
# 83/83 - 6s - loss: 2.7003 - val_loss: 5.2007
#
# Epoch 00107: val_loss did not improve from 4.66340
# Epoch 108/500
# 83/83 - 6s - loss: 2.6482 - val_loss: 5.1809
#
# Epoch 00108: val_loss did not improve from 4.66340
# Epoch 109/500
# 83/83 - 6s - loss: 2.6091 - val_loss: 5.2262
#
# Epoch 00109: val_loss did not improve from 4.66340
# Epoch 110/500
# 83/83 - 6s - loss: 2.5824 - val_loss: 5.2108
#
# Epoch 00110: val_loss did not improve from 4.66340
# Epoch 111/500
# 83/83 - 6s - loss: 2.5562 - val_loss: 5.2423
#
# Epoch 00111: val_loss did not improve from 4.66340
# Epoch 112/500
# 83/83 - 6s - loss: 2.5289 - val_loss: 5.2117
#
# Epoch 00112: val_loss did not improve from 4.66340
# Epoch 113/500
# 83/83 - 6s - loss: 2.5056 - val_loss: 5.2456
#
# Epoch 00113: val_loss did not improve from 4.66340
# Epoch 114/500
# 83/83 - 6s - loss: 2.4955 - val_loss: 5.2525
#
# Epoch 00114: val_loss did not improve from 4.66340
# Epoch 115/500
# 83/83 - 6s - loss: 2.4868 - val_loss: 5.2399
#
# Epoch 00115: val_loss did not improve from 4.66340
# Epoch 116/500
# 83/83 - 6s - loss: 2.4614 - val_loss: 5.2275
#
# Epoch 00116: val_loss did not improve from 4.66340
# Epoch 117/500
# 83/83 - 6s - loss: 2.4341 - val_loss: 5.2260
#
# Epoch 00117: val_loss did not improve from 4.66340
# Epoch 118/500
# 83/83 - 6s - loss: 2.4129 - val_loss: 5.2560
#
# Epoch 00118: val_loss did not improve from 4.66340
# Epoch 119/500
# 83/83 - 6s - loss: 2.3885 - val_loss: 5.2632
#
# Epoch 00119: val_loss did not improve from 4.66340
# Epoch 120/500
# 83/83 - 6s - loss: 2.3699 - val_loss: 5.2507
#
# Epoch 00120: val_loss did not improve from 4.66340
# Epoch 121/500
# 83/83 - 6s - loss: 2.3711 - val_loss: 5.2811
#
# Epoch 00121: val_loss did not improve from 4.66340
# Epoch 122/500
# 83/83 - 6s - loss: 2.3389 - val_loss: 5.3075
#
# Epoch 00122: val_loss did not improve from 4.66340
# Epoch 123/500
# 83/83 - 6s - loss: 2.3259 - val_loss: 5.3072
#
# Epoch 00123: val_loss did not improve from 4.66340
# Epoch 124/500
# 83/83 - 6s - loss: 2.2944 - val_loss: 5.2823
#
# Epoch 00124: val_loss did not improve from 4.66340
# Epoch 125/500
# 83/83 - 6s - loss: 2.2655 - val_loss: 5.2985
#
# Epoch 00125: val_loss did not improve from 4.66340
# Epoch 126/500
# 83/83 - 6s - loss: 2.2452 - val_loss: 5.2838
#
# Epoch 00126: val_loss did not improve from 4.66340
# Epoch 127/500
# 83/83 - 6s - loss: 2.2290 - val_loss: 5.2765
#
# Epoch 00127: val_loss did not improve from 4.66340
# Epoch 128/500
# 83/83 - 6s - loss: 2.2142 - val_loss: 5.3025
#
# Epoch 00128: val_loss did not improve from 4.66340
# Epoch 129/500
# 83/83 - 6s - loss: 2.1875 - val_loss: 5.3170
#
# Epoch 00129: val_loss did not improve from 4.66340
# Epoch 130/500
# 83/83 - 6s - loss: 2.1738 - val_loss: 5.3140
#
# Epoch 00130: val_loss did not improve from 4.66340
# Epoch 131/500
# 83/83 - 6s - loss: 2.1843 - val_loss: 5.3203
#
# Epoch 00131: val_loss did not improve from 4.66340
# Epoch 132/500
# 83/83 - 6s - loss: 2.1669 - val_loss: 5.3627
#
# Epoch 00132: val_loss did not improve from 4.66340
# Epoch 133/500
# 83/83 - 6s - loss: 2.1397 - val_loss: 5.3110
#
# Epoch 00133: val_loss did not improve from 4.66340
# Epoch 134/500
# 83/83 - 6s - loss: 2.1061 - val_loss: 5.3127
#
# Epoch 00134: val_loss did not improve from 4.66340
# Epoch 135/500
# 83/83 - 6s - loss: 2.0874 - val_loss: 5.3612
#
# Epoch 00135: val_loss did not improve from 4.66340
# Epoch 136/500
# 83/83 - 6s - loss: 2.0749 - val_loss: 5.3463
#
# Epoch 00136: val_loss did not improve from 4.66340
# Epoch 137/500
# 83/83 - 6s - loss: 2.0514 - val_loss: 5.3292
#
# Epoch 00137: val_loss did not improve from 4.66340
# Epoch 138/500
# 83/83 - 6s - loss: 2.0366 - val_loss: 5.3448
#
# Epoch 00138: val_loss did not improve from 4.66340
# Epoch 139/500
# 83/83 - 6s - loss: 2.0130 - val_loss: 5.3691
#
# Epoch 00139: val_loss did not improve from 4.66340
# Epoch 140/500
# 83/83 - 6s - loss: 1.9907 - val_loss: 5.3499
#
# Epoch 00140: val_loss did not improve from 4.66340
# Epoch 141/500
# 83/83 - 7s - loss: 1.9743 - val_loss: 5.3780
#
# Epoch 00141: val_loss did not improve from 4.66340
# Epoch 142/500
# 83/83 - 6s - loss: 1.9560 - val_loss: 5.3876
#
# Epoch 00142: val_loss did not improve from 4.66340
# Epoch 143/500
# 83/83 - 6s - loss: 1.9498 - val_loss: 5.3585
#
# Epoch 00143: val_loss did not improve from 4.66340
# Epoch 144/500
# 83/83 - 6s - loss: 1.9300 - val_loss: 5.3813
#
# Epoch 00144: val_loss did not improve from 4.66340
# Epoch 145/500
# 83/83 - 6s - loss: 1.9103 - val_loss: 5.3890
#
# Epoch 00145: val_loss did not improve from 4.66340
# Epoch 146/500
# 83/83 - 6s - loss: 1.9101 - val_loss: 5.4135
#
# Epoch 00146: val_loss did not improve from 4.66340
# Epoch 147/500
# 83/83 - 6s - loss: 1.8919 - val_loss: 5.3940
#
# Epoch 00147: val_loss did not improve from 4.66340
# Epoch 148/500
# 83/83 - 6s - loss: 1.8799 - val_loss: 5.3858
#
# Epoch 00148: val_loss did not improve from 4.66340
# Epoch 149/500
# 83/83 - 6s - loss: 1.8531 - val_loss: 5.3974
#
# Epoch 00149: val_loss did not improve from 4.66340
# Epoch 150/500
# 83/83 - 6s - loss: 1.8291 - val_loss: 5.4106
#
# Epoch 00150: val_loss did not improve from 4.66340
# Epoch 151/500
# 83/83 - 6s - loss: 1.8231 - val_loss: 5.4204
#
# Epoch 00151: val_loss did not improve from 4.66340
# Epoch 152/500
# 83/83 - 6s - loss: 1.8007 - val_loss: 5.4073
#
# Epoch 00152: val_loss did not improve from 4.66340
# Epoch 153/500
# 83/83 - 6s - loss: 1.7819 - val_loss: 5.4096
#
# Epoch 00153: val_loss did not improve from 4.66340
# Epoch 154/500
# 83/83 - 6s - loss: 1.7690 - val_loss: 5.4232
#
# Epoch 00154: val_loss did not improve from 4.66340
# Epoch 155/500
# 83/83 - 6s - loss: 1.7502 - val_loss: 5.4351
#
# Epoch 00155: val_loss did not improve from 4.66340
# Epoch 156/500
# 83/83 - 6s - loss: 1.7299 - val_loss: 5.4476
#
# Epoch 00156: val_loss did not improve from 4.66340
# Epoch 157/500
# 83/83 - 6s - loss: 1.7077 - val_loss: 5.4727
#
# Epoch 00157: val_loss did not improve from 4.66340
# Epoch 158/500
# 83/83 - 6s - loss: 1.6913 - val_loss: 5.4611
#
# Epoch 00158: val_loss did not improve from 4.66340
# Epoch 159/500
# 83/83 - 6s - loss: 1.6834 - val_loss: 5.4586
#
# Epoch 00159: val_loss did not improve from 4.66340
# Epoch 160/500
# 83/83 - 6s - loss: 1.6719 - val_loss: 5.4717
#
# Epoch 00160: val_loss did not improve from 4.66340
# Epoch 161/500
# 83/83 - 6s - loss: 1.6643 - val_loss: 5.4403
#
# Epoch 00161: val_loss did not improve from 4.66340
# Epoch 162/500
# 83/83 - 6s - loss: 1.6630 - val_loss: 5.4580
#
# Epoch 00162: val_loss did not improve from 4.66340
# Epoch 163/500
# 83/83 - 6s - loss: 1.6557 - val_loss: 5.4739
#
# Epoch 00163: val_loss did not improve from 4.66340
# Epoch 164/500
# 83/83 - 6s - loss: 1.6357 - val_loss: 5.4663
#
# Epoch 00164: val_loss did not improve from 4.66340
# Epoch 165/500
# 83/83 - 6s - loss: 1.6048 - val_loss: 5.4967
#
# Epoch 00165: val_loss did not improve from 4.66340
# Epoch 166/500
# 83/83 - 6s - loss: 1.6132 - val_loss: 5.4892
#
# Epoch 00166: val_loss did not improve from 4.66340
# Epoch 167/500
# 83/83 - 6s - loss: 1.5905 - val_loss: 5.4826
#
# Epoch 00167: val_loss did not improve from 4.66340
# Epoch 168/500
# 83/83 - 6s - loss: 1.5798 - val_loss: 5.5057
#
# Epoch 00168: val_loss did not improve from 4.66340
# Epoch 169/500
# 83/83 - 6s - loss: 1.5576 - val_loss: 5.4898
#
# Epoch 00169: val_loss did not improve from 4.66340
# Epoch 170/500
# 83/83 - 6s - loss: 1.5319 - val_loss: 5.5324
#
# Epoch 00170: val_loss did not improve from 4.66340
# Epoch 171/500
# 83/83 - 6s - loss: 1.5138 - val_loss: 5.5159
#
# Epoch 00171: val_loss did not improve from 4.66340
# Epoch 172/500
# 83/83 - 6s - loss: 1.4997 - val_loss: 5.5379
#
# Epoch 00172: val_loss did not improve from 4.66340
# Epoch 173/500
# 83/83 - 6s - loss: 1.5377 - val_loss: 5.5352
#
# Epoch 00173: val_loss did not improve from 4.66340
# Epoch 174/500
# 83/83 - 6s - loss: 1.5144 - val_loss: 5.5225
#
# Epoch 00174: val_loss did not improve from 4.66340
# Epoch 175/500
# 83/83 - 6s - loss: 1.5064 - val_loss: 5.5448
#
# Epoch 00175: val_loss did not improve from 4.66340
# Epoch 176/500
# 83/83 - 6s - loss: 1.4761 - val_loss: 5.5387
#
# Epoch 00176: val_loss did not improve from 4.66340
# Epoch 177/500
# 83/83 - 6s - loss: 1.4503 - val_loss: 5.5527
#
# Epoch 00177: val_loss did not improve from 4.66340
# Epoch 178/500
# 83/83 - 6s - loss: 1.4398 - val_loss: 5.5257
#
# Epoch 00178: val_loss did not improve from 4.66340
# Epoch 179/500
# 83/83 - 7s - loss: 1.4308 - val_loss: 5.5458
#
# Epoch 00179: val_loss did not improve from 4.66340
# Epoch 180/500
# 83/83 - 6s - loss: 1.4178 - val_loss: 5.5349
#
# Epoch 00180: val_loss did not improve from 4.66340
# Epoch 181/500
# 83/83 - 6s - loss: 1.4042 - val_loss: 5.5987
#
# Epoch 00181: val_loss did not improve from 4.66340
# Epoch 182/500
# 83/83 - 6s - loss: 1.3828 - val_loss: 5.5653
#
# Epoch 00182: val_loss did not improve from 4.66340
# Epoch 183/500
# 83/83 - 6s - loss: 1.3930 - val_loss: 5.6249
#
# Epoch 00183: val_loss did not improve from 4.66340
# Epoch 184/500
# 83/83 - 6s - loss: 1.3781 - val_loss: 5.5975
#
# Epoch 00184: val_loss did not improve from 4.66340
# Epoch 185/500
# 83/83 - 6s - loss: 1.3560 - val_loss: 5.6068
#
# Epoch 00185: val_loss did not improve from 4.66340
# Epoch 186/500
# 83/83 - 6s - loss: 1.3406 - val_loss: 5.6157
#
# Epoch 00186: val_loss did not improve from 4.66340
# Epoch 187/500
# 83/83 - 6s - loss: 1.3308 - val_loss: 5.6264
#
# Epoch 00187: val_loss did not improve from 4.66340
# Epoch 188/500
# 83/83 - 6s - loss: 1.3156 - val_loss: 5.6320
#
# Epoch 00188: val_loss did not improve from 4.66340
# Epoch 189/500
# 83/83 - 6s - loss: 1.2977 - val_loss: 5.6239
#
# Epoch 00189: val_loss did not improve from 4.66340
# Epoch 190/500
# 83/83 - 6s - loss: 1.2940 - val_loss: 5.6546
#
# Epoch 00190: val_loss did not improve from 4.66340
# Epoch 191/500
# 83/83 - 6s - loss: 1.2818 - val_loss: 5.6194
#
# Epoch 00191: val_loss did not improve from 4.66340
# Epoch 192/500
# 83/83 - 6s - loss: 1.2668 - val_loss: 5.6574
#
# Epoch 00192: val_loss did not improve from 4.66340
# Epoch 193/500
# 83/83 - 6s - loss: 1.2492 - val_loss: 5.6634
#
# Epoch 00193: val_loss did not improve from 4.66340
# Epoch 194/500
# 83/83 - 6s - loss: 1.2361 - val_loss: 5.6714
#
# Epoch 00194: val_loss did not improve from 4.66340
# Epoch 195/500
# 83/83 - 6s - loss: 1.2272 - val_loss: 5.6793
#
# Epoch 00195: val_loss did not improve from 4.66340
# Epoch 196/500
# 83/83 - 6s - loss: 1.2281 - val_loss: 5.6820
#
# Epoch 00196: val_loss did not improve from 4.66340
# Epoch 197/500
# 83/83 - 6s - loss: 1.2149 - val_loss: 5.6930
#
# Epoch 00197: val_loss did not improve from 4.66340
# Epoch 198/500
# 83/83 - 6s - loss: 1.2005 - val_loss: 5.7125
#
# Epoch 00198: val_loss did not improve from 4.66340
# Epoch 199/500
# 83/83 - 6s - loss: 1.1844 - val_loss: 5.6842
#
# Epoch 00199: val_loss did not improve from 4.66340
# Epoch 200/500
# 83/83 - 6s - loss: 1.1709 - val_loss: 5.6950
#
# Epoch 00200: val_loss did not improve from 4.66340
# Epoch 201/500
# 83/83 - 6s - loss: 1.1635 - val_loss: 5.7055
#
# Epoch 00201: val_loss did not improve from 4.66340
# Epoch 202/500
# 83/83 - 6s - loss: 1.1563 - val_loss: 5.7052
#
# Epoch 00202: val_loss did not improve from 4.66340
# Epoch 203/500
# 83/83 - 6s - loss: 1.1592 - val_loss: 5.7239
#
# Epoch 00203: val_loss did not improve from 4.66340
# Epoch 204/500
# 83/83 - 6s - loss: 1.1574 - val_loss: 5.7213
#
# Epoch 00204: val_loss did not improve from 4.66340
# Epoch 205/500
# 83/83 - 6s - loss: 1.1439 - val_loss: 5.7315
#
# Epoch 00205: val_loss did not improve from 4.66340
# Epoch 206/500
# 83/83 - 6s - loss: 1.1242 - val_loss: 5.7446
#
# Epoch 00206: val_loss did not improve from 4.66340
# Epoch 207/500
# 83/83 - 6s - loss: 1.1073 - val_loss: 5.7542
#
# Epoch 00207: val_loss did not improve from 4.66340
# Epoch 208/500
# 83/83 - 6s - loss: 1.0902 - val_loss: 5.7454
#
# Epoch 00208: val_loss did not improve from 4.66340
# Epoch 209/500
# 83/83 - 6s - loss: 1.0842 - val_loss: 5.7636
#
# Epoch 00209: val_loss did not improve from 4.66340
# Epoch 210/500
# 83/83 - 6s - loss: 1.0786 - val_loss: 5.7589
#
# Epoch 00210: val_loss did not improve from 4.66340
# Epoch 211/500
# 83/83 - 6s - loss: 1.0684 - val_loss: 5.7799
#
# Epoch 00211: val_loss did not improve from 4.66340
# Epoch 212/500
# 83/83 - 6s - loss: 1.0581 - val_loss: 5.7925
#
# Epoch 00212: val_loss did not improve from 4.66340
# Epoch 213/500
# 83/83 - 6s - loss: 1.0465 - val_loss: 5.7848
#
# Epoch 00213: val_loss did not improve from 4.66340
# Epoch 214/500
# 83/83 - 6s - loss: 1.0430 - val_loss: 5.8124
#
# Epoch 00214: val_loss did not improve from 4.66340
# Epoch 215/500
# 83/83 - 6s - loss: 1.0567 - val_loss: 5.8154
#
# Epoch 00215: val_loss did not improve from 4.66340
# Epoch 216/500
# 83/83 - 6s - loss: 1.0575 - val_loss: 5.8445
#
# Epoch 00216: val_loss did not improve from 4.66340
# Epoch 217/500
# 83/83 - 6s - loss: 1.0414 - val_loss: 5.8295
#
# Epoch 00217: val_loss did not improve from 4.66340
# Epoch 218/500
# 83/83 - 6s - loss: 1.0149 - val_loss: 5.8421
#
# Epoch 00218: val_loss did not improve from 4.66340
# Epoch 219/500
# 83/83 - 6s - loss: 1.0030 - val_loss: 5.8141
#
# Epoch 00219: val_loss did not improve from 4.66340
# Epoch 220/500
# 83/83 - 6s - loss: 0.9914 - val_loss: 5.8291
#
# Epoch 00220: val_loss did not improve from 4.66340
# Epoch 221/500
# 83/83 - 6s - loss: 0.9736 - val_loss: 5.8338
#
# Epoch 00221: val_loss did not improve from 4.66340
# Epoch 222/500
# 83/83 - 6s - loss: 0.9633 - val_loss: 5.8361
#
# Epoch 00222: val_loss did not improve from 4.66340
# Epoch 223/500
# 83/83 - 6s - loss: 0.9627 - val_loss: 5.8799
#
# Epoch 00223: val_loss did not improve from 4.66340
# Epoch 224/500
# 83/83 - 6s - loss: 0.9580 - val_loss: 5.8621
#
# Epoch 00224: val_loss did not improve from 4.66340
# Epoch 225/500
# 83/83 - 6s - loss: 0.9473 - val_loss: 5.8697
#
# Epoch 00225: val_loss did not improve from 4.66340
# Epoch 226/500
# 83/83 - 6s - loss: 0.9464 - val_loss: 5.9056
#
# Epoch 00226: val_loss did not improve from 4.66340
# Epoch 227/500
# 83/83 - 6s - loss: 0.9944 - val_loss: 5.9054
#
# Epoch 00227: val_loss did not improve from 4.66340
# Epoch 228/500
# 83/83 - 6s - loss: 0.9638 - val_loss: 5.8932
#
# Epoch 00228: val_loss did not improve from 4.66340
# Epoch 229/500
# 83/83 - 6s - loss: 0.9276 - val_loss: 5.9030
#
# Epoch 00229: val_loss did not improve from 4.66340
# Epoch 230/500
# 83/83 - 6s - loss: 0.9117 - val_loss: 5.8916
#
# Epoch 00230: val_loss did not improve from 4.66340
# Epoch 231/500
# 83/83 - 6s - loss: 0.8986 - val_loss: 5.9082
#
# Epoch 00231: val_loss did not improve from 4.66340
# Epoch 232/500
# 83/83 - 6s - loss: 0.8802 - val_loss: 5.9057
#
# Epoch 00232: val_loss did not improve from 4.66340
# Epoch 233/500
# 83/83 - 6s - loss: 0.8740 - val_loss: 5.9234
#
# Epoch 00233: val_loss did not improve from 4.66340
# Epoch 234/500
# 83/83 - 6s - loss: 0.8730 - val_loss: 5.9364
#
# Epoch 00234: val_loss did not improve from 4.66340
# Epoch 235/500
# 83/83 - 6s - loss: 0.8687 - val_loss: 5.9275
#
# Epoch 00235: val_loss did not improve from 4.66340
# Epoch 236/500
# 83/83 - 6s - loss: 0.8591 - val_loss: 5.9729
#
# Epoch 00236: val_loss did not improve from 4.66340
# Epoch 237/500
# 83/83 - 6s - loss: 0.8641 - val_loss: 5.9498
#
# Epoch 00237: val_loss did not improve from 4.66340
# Epoch 238/500
# 83/83 - 6s - loss: 0.8650 - val_loss: 5.9641
#
# Epoch 00238: val_loss did not improve from 4.66340
# Epoch 239/500
# 83/83 - 6s - loss: 0.8634 - val_loss: 5.9672
#
# Epoch 00239: val_loss did not improve from 4.66340
# Epoch 240/500
# 83/83 - 6s - loss: 0.8400 - val_loss: 5.9629
#
# Epoch 00240: val_loss did not improve from 4.66340
# Epoch 241/500
# 83/83 - 6s - loss: 0.8190 - val_loss: 5.9822
#
# Epoch 00241: val_loss did not improve from 4.66340
# Epoch 242/500
# 83/83 - 6s - loss: 0.8073 - val_loss: 6.0123
#
# Epoch 00242: val_loss did not improve from 4.66340
# Epoch 243/500
# 83/83 - 6s - loss: 0.7964 - val_loss: 5.9987
#
# Epoch 00243: val_loss did not improve from 4.66340
# Epoch 244/500
# 83/83 - 6s - loss: 0.8021 - val_loss: 6.0073
#
# Epoch 00244: val_loss did not improve from 4.66340
# Epoch 245/500
# 83/83 - 6s - loss: 0.8233 - val_loss: 6.0530
#
# Epoch 00245: val_loss did not improve from 4.66340
# Epoch 246/500
# 83/83 - 6s - loss: 0.8151 - val_loss: 5.9931
#
# Epoch 00246: val_loss did not improve from 4.66340
# Epoch 247/500
# 83/83 - 6s - loss: 0.8055 - val_loss: 6.0265
#
# Epoch 00247: val_loss did not improve from 4.66340
# Epoch 248/500
# 83/83 - 6s - loss: 0.7919 - val_loss: 6.0335
#
# Epoch 00248: val_loss did not improve from 4.66340
# Epoch 249/500
# 83/83 - 6s - loss: 0.7750 - val_loss: 6.0426
#
# Epoch 00249: val_loss did not improve from 4.66340
# Epoch 250/500
# 83/83 - 6s - loss: 0.7521 - val_loss: 6.0272
#
# Epoch 00250: val_loss did not improve from 4.66340
# Epoch 251/500
# 83/83 - 6s - loss: 0.7369 - val_loss: 6.0446
#
# Epoch 00251: val_loss did not improve from 4.66340
# Epoch 252/500
# 83/83 - 6s - loss: 0.7282 - val_loss: 6.0569
#
# Epoch 00252: val_loss did not improve from 4.66340
# Epoch 253/500
# 83/83 - 6s - loss: 0.7239 - val_loss: 6.0651
#
# Epoch 00253: val_loss did not improve from 4.66340
# Epoch 254/500
# 83/83 - 6s - loss: 0.7246 - val_loss: 6.0909
#
# Epoch 00254: val_loss did not improve from 4.66340
# Epoch 255/500
# 83/83 - 6s - loss: 0.7292 - val_loss: 6.0858
#
# Epoch 00255: val_loss did not improve from 4.66340
# Epoch 256/500
# 83/83 - 6s - loss: 0.7343 - val_loss: 6.0795
#
# Epoch 00256: val_loss did not improve from 4.66340
# Epoch 257/500
# 83/83 - 6s - loss: 0.7442 - val_loss: 6.1047
#
# Epoch 00257: val_loss did not improve from 4.66340
# Epoch 258/500
# 83/83 - 6s - loss: 0.7590 - val_loss: 6.0931
#
# Epoch 00258: val_loss did not improve from 4.66340
# Epoch 259/500
# 83/83 - 6s - loss: 0.7468 - val_loss: 6.0935
#
# Epoch 00259: val_loss did not improve from 4.66340
# Epoch 260/500
# 83/83 - 6s - loss: 0.7290 - val_loss: 6.0918
#
# Epoch 00260: val_loss did not improve from 4.66340
# Epoch 261/500
# 83/83 - 6s - loss: 0.7055 - val_loss: 6.1096
#
# Epoch 00261: val_loss did not improve from 4.66340
# Epoch 262/500
# 83/83 - 6s - loss: 0.6850 - val_loss: 6.1158
#
# Epoch 00262: val_loss did not improve from 4.66340
# Epoch 263/500
# 83/83 - 6s - loss: 0.6663 - val_loss: 6.1425
#
# Epoch 00263: val_loss did not improve from 4.66340
# Epoch 264/500
# 83/83 - 6s - loss: 0.6519 - val_loss: 6.1182
#
# Epoch 00264: val_loss did not improve from 4.66340
# Epoch 265/500
# 83/83 - 6s - loss: 0.6498 - val_loss: 6.1232
#
# Epoch 00265: val_loss did not improve from 4.66340
# Epoch 266/500
# 83/83 - 6s - loss: 0.6559 - val_loss: 6.1468
#
# Epoch 00266: val_loss did not improve from 4.66340
# Epoch 267/500
# 83/83 - 6s - loss: 0.6593 - val_loss: 6.1624
#
# Epoch 00267: val_loss did not improve from 4.66340
# Epoch 268/500
# 83/83 - 6s - loss: 0.6726 - val_loss: 6.1469
#
# Epoch 00268: val_loss did not improve from 4.66340
# Epoch 269/500
# 83/83 - 6s - loss: 0.7002 - val_loss: 6.1810
#
# Epoch 00269: val_loss did not improve from 4.66340
# Epoch 270/500
# 83/83 - 6s - loss: 0.6744 - val_loss: 6.1820
#
# Epoch 00270: val_loss did not improve from 4.66340
# Epoch 271/500
# 83/83 - 6s - loss: 0.6677 - val_loss: 6.1710
#
# Epoch 00271: val_loss did not improve from 4.66340
# Epoch 272/500
# 83/83 - 6s - loss: 0.6695 - val_loss: 6.1838
#
# Epoch 00272: val_loss did not improve from 4.66340
# Epoch 273/500
# 83/83 - 6s - loss: 0.6408 - val_loss: 6.1605
#
# Epoch 00273: val_loss did not improve from 4.66340
# Epoch 274/500
# 83/83 - 6s - loss: 0.6317 - val_loss: 6.1738
#
# Epoch 00274: val_loss did not improve from 4.66340
# Epoch 275/500
# 83/83 - 6s - loss: 0.6263 - val_loss: 6.2110
#
# Epoch 00275: val_loss did not improve from 4.66340
# Epoch 276/500
# 83/83 - 6s - loss: 0.6143 - val_loss: 6.2163
#
# Epoch 00276: val_loss did not improve from 4.66340
# Epoch 277/500
# 83/83 - 6s - loss: 0.6009 - val_loss: 6.2266
#
# Epoch 00277: val_loss did not improve from 4.66340
# Epoch 278/500
# 83/83 - 6s - loss: 0.5854 - val_loss: 6.2111
#
# Epoch 00278: val_loss did not improve from 4.66340
# Epoch 279/500
# 83/83 - 6s - loss: 0.5863 - val_loss: 6.2323
#
# Epoch 00279: val_loss did not improve from 4.66340
# Epoch 280/500
# 83/83 - 6s - loss: 0.6075 - val_loss: 6.2263
#
# Epoch 00280: val_loss did not improve from 4.66340
# Epoch 281/500
# 83/83 - 6s - loss: 0.6099 - val_loss: 6.2436
#
# Epoch 00281: val_loss did not improve from 4.66340
# Epoch 282/500
# 83/83 - 6s - loss: 0.5931 - val_loss: 6.2575
#
# Epoch 00282: val_loss did not improve from 4.66340
# Epoch 283/500
# 83/83 - 6s - loss: 0.5718 - val_loss: 6.2427
#
# Epoch 00283: val_loss did not improve from 4.66340
# Epoch 284/500
# 83/83 - 6s - loss: 0.5566 - val_loss: 6.2564
#
# Epoch 00284: val_loss did not improve from 4.66340
# Epoch 285/500
# 83/83 - 6s - loss: 0.5490 - val_loss: 6.2771
#
# Epoch 00285: val_loss did not improve from 4.66340
# Epoch 286/500
# 83/83 - 6s - loss: 0.5480 - val_loss: 6.2684
#
# Epoch 00286: val_loss did not improve from 4.66340
# Epoch 287/500
# 83/83 - 6s - loss: 0.5464 - val_loss: 6.3156
#
# Epoch 00287: val_loss did not improve from 4.66340
# Epoch 288/500
# 83/83 - 6s - loss: 0.5579 - val_loss: 6.2821
#
# Epoch 00288: val_loss did not improve from 4.66340
# Epoch 289/500
# 83/83 - 7s - loss: 0.5666 - val_loss: 6.2859
#
# Epoch 00289: val_loss did not improve from 4.66340
# Epoch 290/500
# 83/83 - 6s - loss: 0.5646 - val_loss: 6.3040
#
# Epoch 00290: val_loss did not improve from 4.66340
# Epoch 291/500
# 83/83 - 6s - loss: 0.5570 - val_loss: 6.3434
#
# Epoch 00291: val_loss did not improve from 4.66340
# Epoch 292/500
# 83/83 - 6s - loss: 0.5553 - val_loss: 6.2819
#
# Epoch 00292: val_loss did not improve from 4.66340
# Epoch 293/500
# 83/83 - 6s - loss: 0.5632 - val_loss: 6.3439
#
# Epoch 00293: val_loss did not improve from 4.66340
# Epoch 294/500
# 83/83 - 6s - loss: 0.5548 - val_loss: 6.3595
#
# Epoch 00294: val_loss did not improve from 4.66340
# Epoch 295/500
# 83/83 - 6s - loss: 0.5401 - val_loss: 6.3280
#
# Epoch 00295: val_loss did not improve from 4.66340
# Epoch 296/500
# 83/83 - 6s - loss: 0.5238 - val_loss: 6.3402
#
# Epoch 00296: val_loss did not improve from 4.66340
# Epoch 297/500
# 83/83 - 6s - loss: 0.5194 - val_loss: 6.3387
#
# Epoch 00297: val_loss did not improve from 4.66340
# Epoch 298/500
# 83/83 - 6s - loss: 0.5045 - val_loss: 6.3322
#
# Epoch 00298: val_loss did not improve from 4.66340
# Epoch 299/500
# 83/83 - 6s - loss: 0.4884 - val_loss: 6.3478
#
# Epoch 00299: val_loss did not improve from 4.66340
# Epoch 300/500
# 83/83 - 6s - loss: 0.4784 - val_loss: 6.3619
#
# Epoch 00300: val_loss did not improve from 4.66340
# Epoch 301/500
# 83/83 - 6s - loss: 0.4758 - val_loss: 6.3721
#
# Epoch 00301: val_loss did not improve from 4.66340
# Epoch 302/500
# 83/83 - 6s - loss: 0.4766 - val_loss: 6.3658
#
# Epoch 00302: val_loss did not improve from 4.66340
# Epoch 303/500
# 83/83 - 6s - loss: 0.4794 - val_loss: 6.3932
#
# Epoch 00303: val_loss did not improve from 4.66340
# Epoch 304/500
# 83/83 - 6s - loss: 0.4838 - val_loss: 6.3991
#
# Epoch 00304: val_loss did not improve from 4.66340
# Epoch 305/500
# 83/83 - 6s - loss: 0.4904 - val_loss: 6.4246
#
# Epoch 00305: val_loss did not improve from 4.66340
# Epoch 306/500
# 83/83 - 6s - loss: 0.5023 - val_loss: 6.4505
#
# Epoch 00306: val_loss did not improve from 4.66340
# Epoch 307/500
# 83/83 - 6s - loss: 0.5003 - val_loss: 6.3973
#
# Epoch 00307: val_loss did not improve from 4.66340
# Epoch 308/500
# 83/83 - 6s - loss: 0.4915 - val_loss: 6.4467
#
# Epoch 00308: val_loss did not improve from 4.66340
# Epoch 309/500
# 83/83 - 6s - loss: 0.4879 - val_loss: 6.4184
#
# Epoch 00309: val_loss did not improve from 4.66340
# Epoch 310/500
# 83/83 - 6s - loss: 0.4756 - val_loss: 6.4129
#
# Epoch 00310: val_loss did not improve from 4.66340
# Epoch 311/500
# 83/83 - 6s - loss: 0.4607 - val_loss: 6.4460
#
# Epoch 00311: val_loss did not improve from 4.66340
# Epoch 312/500
# 83/83 - 6s - loss: 0.4486 - val_loss: 6.4420
#
# Epoch 00312: val_loss did not improve from 4.66340
# Epoch 313/500
# 83/83 - 6s - loss: 0.4464 - val_loss: 6.4573
#
# Epoch 00313: val_loss did not improve from 4.66340
# Epoch 314/500
# 83/83 - 6s - loss: 0.4442 - val_loss: 6.4676
#
# Epoch 00314: val_loss did not improve from 4.66340
# Epoch 315/500
# 83/83 - 6s - loss: 0.4439 - val_loss: 6.4785
#
# Epoch 00315: val_loss did not improve from 4.66340
# Epoch 316/500
# 83/83 - 6s - loss: 0.4500 - val_loss: 6.4733
#
# Epoch 00316: val_loss did not improve from 4.66340
# Epoch 317/500
# 83/83 - 6s - loss: 0.4496 - val_loss: 6.5002
#
# Epoch 00317: val_loss did not improve from 4.66340
# Epoch 318/500
# 83/83 - 6s - loss: 0.4407 - val_loss: 6.4766
#
# Epoch 00318: val_loss did not improve from 4.66340
# Epoch 319/500
# 83/83 - 6s - loss: 0.4366 - val_loss: 6.5109
#
# Epoch 00319: val_loss did not improve from 4.66340
# Epoch 320/500
# 83/83 - 6s - loss: 0.4466 - val_loss: 6.5067
#
# Epoch 00320: val_loss did not improve from 4.66340
# Epoch 321/500
# 83/83 - 7s - loss: 0.4361 - val_loss: 6.5375
#
# Epoch 00321: val_loss did not improve from 4.66340
# Epoch 322/500
# 83/83 - 6s - loss: 0.4230 - val_loss: 6.5243
#
# Epoch 00322: val_loss did not improve from 4.66340
# Epoch 323/500
# 83/83 - 6s - loss: 0.4258 - val_loss: 6.5027
#
# Epoch 00323: val_loss did not improve from 4.66340
# Epoch 324/500
# 83/83 - 6s - loss: 0.4330 - val_loss: 6.5161
#
# Epoch 00324: val_loss did not improve from 4.66340
# Epoch 325/500
# 83/83 - 6s - loss: 0.4347 - val_loss: 6.5313
#
# Epoch 00325: val_loss did not improve from 4.66340
# Epoch 326/500
# 83/83 - 6s - loss: 0.4376 - val_loss: 6.5768
#
# Epoch 00326: val_loss did not improve from 4.66340
# Epoch 327/500
# 83/83 - 6s - loss: 0.4370 - val_loss: 6.5319
#
# Epoch 00327: val_loss did not improve from 4.66340
# Epoch 328/500
# 83/83 - 6s - loss: 0.4256 - val_loss: 6.5591
#
# Epoch 00328: val_loss did not improve from 4.66340
# Epoch 329/500
# 83/83 - 6s - loss: 0.4110 - val_loss: 6.5394
#
# Epoch 00329: val_loss did not improve from 4.66340
# Epoch 330/500
# 83/83 - 6s - loss: 0.4011 - val_loss: 6.5944
#
# Epoch 00330: val_loss did not improve from 4.66340
# Epoch 331/500
# 83/83 - 6s - loss: 0.3893 - val_loss: 6.5670
#
# Epoch 00331: val_loss did not improve from 4.66340
# Epoch 332/500
# 83/83 - 6s - loss: 0.3745 - val_loss: 6.5697
#
# Epoch 00332: val_loss did not improve from 4.66340
# Epoch 333/500
# 83/83 - 6s - loss: 0.3701 - val_loss: 6.5621
#
# Epoch 00333: val_loss did not improve from 4.66340
# Epoch 334/500
# 83/83 - 6s - loss: 0.3595 - val_loss: 6.5709
#
# Epoch 00334: val_loss did not improve from 4.66340
# Epoch 335/500
# 83/83 - 6s - loss: 0.3511 - val_loss: 6.5822
#
# Epoch 00335: val_loss did not improve from 4.66340
# Epoch 336/500
# 83/83 - 6s - loss: 0.3542 - val_loss: 6.5785
#
# Epoch 00336: val_loss did not improve from 4.66340
# Epoch 337/500
# 83/83 - 6s - loss: 0.3577 - val_loss: 6.6062
#
# Epoch 00337: val_loss did not improve from 4.66340
# Epoch 338/500
# 83/83 - 6s - loss: 0.3675 - val_loss: 6.6244
#
# Epoch 00338: val_loss did not improve from 4.66340
# Epoch 339/500
# 83/83 - 6s - loss: 0.3837 - val_loss: 6.6173
#
# Epoch 00339: val_loss did not improve from 4.66340
# Epoch 340/500
# 83/83 - 6s - loss: 0.4160 - val_loss: 6.6509
#
# Epoch 00340: val_loss did not improve from 4.66340
# Epoch 341/500
# 83/83 - 6s - loss: 0.4238 - val_loss: 6.6332
#
# Epoch 00341: val_loss did not improve from 4.66340
# Epoch 342/500
# 83/83 - 6s - loss: 0.4041 - val_loss: 6.6302
#
# Epoch 00342: val_loss did not improve from 4.66340
# Epoch 343/500
# 83/83 - 6s - loss: 0.4001 - val_loss: 6.6253
#
# Epoch 00343: val_loss did not improve from 4.66340
# Epoch 344/500
# 83/83 - 6s - loss: 0.3879 - val_loss: 6.6240
#
# Epoch 00344: val_loss did not improve from 4.66340
# Epoch 345/500
# 83/83 - 6s - loss: 0.3623 - val_loss: 6.6347
#
# Epoch 00345: val_loss did not improve from 4.66340
# Epoch 346/500
# 83/83 - 6s - loss: 0.3486 - val_loss: 6.6517
#
# Epoch 00346: val_loss did not improve from 4.66340
# Epoch 347/500
# 83/83 - 6s - loss: 0.3305 - val_loss: 6.6420
#
# Epoch 00347: val_loss did not improve from 4.66340
# Epoch 348/500
# 83/83 - 6s - loss: 0.3245 - val_loss: 6.6729
#
# Epoch 00348: val_loss did not improve from 4.66340
# Epoch 349/500
# 83/83 - 6s - loss: 0.3304 - val_loss: 6.6604
#
# Epoch 00349: val_loss did not improve from 4.66340
# Epoch 350/500
# 83/83 - 6s - loss: 0.3376 - val_loss: 6.7047
#
# Epoch 00350: val_loss did not improve from 4.66340
# Epoch 351/500
# 83/83 - 6s - loss: 0.3441 - val_loss: 6.6680
#
# Epoch 00351: val_loss did not improve from 4.66340
# Epoch 352/500
# 83/83 - 6s - loss: 0.3315 - val_loss: 6.6632
#
# Epoch 00352: val_loss did not improve from 4.66340
# Epoch 353/500
# 83/83 - 6s - loss: 0.3222 - val_loss: 6.6583
#
# Epoch 00353: val_loss did not improve from 4.66340
# Epoch 354/500
# 83/83 - 6s - loss: 0.3137 - val_loss: 6.6974
#
# Epoch 00354: val_loss did not improve from 4.66340
# Epoch 355/500
# 83/83 - 6s - loss: 0.3084 - val_loss: 6.7166
#
# Epoch 00355: val_loss did not improve from 4.66340
# Epoch 356/500
# 83/83 - 6s - loss: 0.3158 - val_loss: 6.7108
#
# Epoch 00356: val_loss did not improve from 4.66340
# Epoch 357/500
# 83/83 - 6s - loss: 0.3262 - val_loss: 6.7503
#
# Epoch 00357: val_loss did not improve from 4.66340
# Epoch 358/500
# 83/83 - 6s - loss: 0.3504 - val_loss: 6.7447
#
# Epoch 00358: val_loss did not improve from 4.66340
# Epoch 359/500
# 83/83 - 6s - loss: 0.3785 - val_loss: 6.7163
#
# Epoch 00359: val_loss did not improve from 4.66340
# Epoch 360/500
# 83/83 - 6s - loss: 0.3846 - val_loss: 6.6845
#
# Epoch 00360: val_loss did not improve from 4.66340
# Epoch 361/500
# 83/83 - 6s - loss: 0.3692 - val_loss: 6.7260
#
# Epoch 00361: val_loss did not improve from 4.66340
# Epoch 362/500
# 83/83 - 6s - loss: 0.3412 - val_loss: 6.7220
#
# Epoch 00362: val_loss did not improve from 4.66340
# Epoch 363/500
# 83/83 - 6s - loss: 0.3127 - val_loss: 6.7077
#
# Epoch 00363: val_loss did not improve from 4.66340
# Epoch 364/500
# 83/83 - 6s - loss: 0.2923 - val_loss: 6.7270
#
# Epoch 00364: val_loss did not improve from 4.66340
# Epoch 365/500
# 83/83 - 6s - loss: 0.2775 - val_loss: 6.7286
#
# Epoch 00365: val_loss did not improve from 4.66340
# Epoch 366/500
# 83/83 - 6s - loss: 0.2682 - val_loss: 6.7448
#
# Epoch 00366: val_loss did not improve from 4.66340
# Epoch 367/500
# 83/83 - 6s - loss: 0.2612 - val_loss: 6.7401
#
# Epoch 00367: val_loss did not improve from 4.66340
# Epoch 368/500
# 83/83 - 6s - loss: 0.2570 - val_loss: 6.7594
#
# Epoch 00368: val_loss did not improve from 4.66340
# Epoch 369/500
# 83/83 - 6s - loss: 0.2555 - val_loss: 6.7565
#
# Epoch 00369: val_loss did not improve from 4.66340
# Epoch 370/500
# 83/83 - 6s - loss: 0.2538 - val_loss: 6.7764
#
# Epoch 00370: val_loss did not improve from 4.66340
# Epoch 371/500
# 83/83 - 6s - loss: 0.2575 - val_loss: 6.7836
#
# Epoch 00371: val_loss did not improve from 4.66340
# Epoch 372/500
# 83/83 - 6s - loss: 0.2669 - val_loss: 6.7902
#
# Epoch 00372: val_loss did not improve from 4.66340
# Epoch 373/500
# 83/83 - 6s - loss: 0.2899 - val_loss: 6.8005
#
# Epoch 00373: val_loss did not improve from 4.66340
# Epoch 374/500
# 83/83 - 6s - loss: 0.3444 - val_loss: 6.8332
#
# Epoch 00374: val_loss did not improve from 4.66340
# Epoch 375/500
# 83/83 - 6s - loss: 0.3831 - val_loss: 6.8217
#
# Epoch 00375: val_loss did not improve from 4.66340
# Epoch 376/500
# 83/83 - 6s - loss: 0.3901 - val_loss: 6.8180
#
# Epoch 00376: val_loss did not improve from 4.66340
# Epoch 377/500
# 83/83 - 6s - loss: 0.3508 - val_loss: 6.8084
#
# Epoch 00377: val_loss did not improve from 4.66340
# Epoch 378/500
# 83/83 - 6s - loss: 0.3099 - val_loss: 6.8001
#
# Epoch 00378: val_loss did not improve from 4.66340
# Epoch 379/500
# 83/83 - 6s - loss: 0.2741 - val_loss: 6.8409
#
# Epoch 00379: val_loss did not improve from 4.66340
# Epoch 380/500
# 83/83 - 6s - loss: 0.2523 - val_loss: 6.8183
#
# Epoch 00380: val_loss did not improve from 4.66340
# Epoch 381/500
# 83/83 - 6s - loss: 0.2363 - val_loss: 6.8132
#
# Epoch 00381: val_loss did not improve from 4.66340
# Epoch 382/500
# 83/83 - 6s - loss: 0.2291 - val_loss: 6.8320
#
# Epoch 00382: val_loss did not improve from 4.66340
# Epoch 383/500
# 83/83 - 6s - loss: 0.2246 - val_loss: 6.8343
#
# Epoch 00383: val_loss did not improve from 4.66340
# Epoch 384/500
# 83/83 - 6s - loss: 0.2243 - val_loss: 6.8502
#
# Epoch 00384: val_loss did not improve from 4.66340
# Epoch 385/500
# 83/83 - 6s - loss: 0.2253 - val_loss: 6.8335
#
# Epoch 00385: val_loss did not improve from 4.66340
# Epoch 386/500
# 83/83 - 6s - loss: 0.2278 - val_loss: 6.8584
#
# Epoch 00386: val_loss did not improve from 4.66340
# Epoch 387/500
# 83/83 - 6s - loss: 0.2334 - val_loss: 6.8919
#
# Epoch 00387: val_loss did not improve from 4.66340
# Epoch 388/500
# 83/83 - 6s - loss: 0.2561 - val_loss: 6.8889
#
# Epoch 00388: val_loss did not improve from 4.66340
# Epoch 389/500
# 83/83 - 6s - loss: 0.2889 - val_loss: 6.9057
#
# Epoch 00389: val_loss did not improve from 4.66340
# Epoch 390/500
# 83/83 - 6s - loss: 0.3251 - val_loss: 6.8468
#
# Epoch 00390: val_loss did not improve from 4.66340
# Epoch 391/500
# 83/83 - 6s - loss: 0.3368 - val_loss: 6.8617
#
# Epoch 00391: val_loss did not improve from 4.66340
# Epoch 392/500
# 83/83 - 6s - loss: 0.3126 - val_loss: 6.8918
#
# Epoch 00392: val_loss did not improve from 4.66340
# Epoch 393/500
# 83/83 - 6s - loss: 0.2844 - val_loss: 6.8735
#
# Epoch 00393: val_loss did not improve from 4.66340
# Epoch 394/500
# 83/83 - 6s - loss: 0.2602 - val_loss: 6.8695
#
# Epoch 00394: val_loss did not improve from 4.66340
# Epoch 395/500
# 83/83 - 6s - loss: 0.2400 - val_loss: 6.8746
#
# Epoch 00395: val_loss did not improve from 4.66340
# Epoch 396/500
# 83/83 - 6s - loss: 0.2265 - val_loss: 6.9162
#
# Epoch 00396: val_loss did not improve from 4.66340
# Epoch 397/500
# 83/83 - 6s - loss: 0.2157 - val_loss: 6.9102
#
# Epoch 00397: val_loss did not improve from 4.66340
# Epoch 398/500
# 83/83 - 6s - loss: 0.2160 - val_loss: 6.9152
#
# Epoch 00398: val_loss did not improve from 4.66340
# Epoch 399/500
# 83/83 - 6s - loss: 0.2214 - val_loss: 6.8997
#
# Epoch 00399: val_loss did not improve from 4.66340
# Epoch 400/500
# 83/83 - 6s - loss: 0.2335 - val_loss: 6.9707
#
# Epoch 00400: val_loss did not improve from 4.66340
# Epoch 401/500
# 83/83 - 6s - loss: 0.2482 - val_loss: 6.9573
#
# Epoch 00401: val_loss did not improve from 4.66340
# Epoch 402/500
# 83/83 - 6s - loss: 0.2917 - val_loss: 6.9283
#
# Epoch 00402: val_loss did not improve from 4.66340
# Epoch 403/500
# 83/83 - 6s - loss: 0.3151 - val_loss: 6.9198
#
# Epoch 00403: val_loss did not improve from 4.66340
# Epoch 404/500
# 83/83 - 6s - loss: 0.2780 - val_loss: 6.9098
#
# Epoch 00404: val_loss did not improve from 4.66340
# Epoch 405/500
# 83/83 - 6s - loss: 0.2471 - val_loss: 6.9534
#
# Epoch 00405: val_loss did not improve from 4.66340
# Epoch 406/500
# 83/83 - 6s - loss: 0.2213 - val_loss: 6.9573
#
# Epoch 00406: val_loss did not improve from 4.66340
# Epoch 407/500
# 83/83 - 6s - loss: 0.2058 - val_loss: 6.9528
#
# Epoch 00407: val_loss did not improve from 4.66340
# Epoch 408/500
# 83/83 - 6s - loss: 0.1937 - val_loss: 6.9400
#
# Epoch 00408: val_loss did not improve from 4.66340
# Epoch 409/500
# 83/83 - 6s - loss: 0.1828 - val_loss: 6.9452
#
# Epoch 00409: val_loss did not improve from 4.66340
# Epoch 410/500
# 83/83 - 6s - loss: 0.1779 - val_loss: 6.9477
#
# Epoch 00410: val_loss did not improve from 4.66340
# Epoch 411/500
# 83/83 - 6s - loss: 0.1750 - val_loss: 6.9651
#
# Epoch 00411: val_loss did not improve from 4.66340
# Epoch 412/500
# 83/83 - 6s - loss: 0.1776 - val_loss: 6.9830
#
# Epoch 00412: val_loss did not improve from 4.66340
# Epoch 413/500
# 83/83 - 6s - loss: 0.1822 - val_loss: 6.9770
#
# Epoch 00413: val_loss did not improve from 4.66340
# Epoch 414/500
# 83/83 - 6s - loss: 0.1856 - val_loss: 6.9699
#
# Epoch 00414: val_loss did not improve from 4.66340
# Epoch 415/500
# 83/83 - 6s - loss: 0.2090 - val_loss: 7.0360
#
# Epoch 00415: val_loss did not improve from 4.66340
# Epoch 416/500
# 83/83 - 6s - loss: 0.2628 - val_loss: 7.0416
#
# Epoch 00416: val_loss did not improve from 4.66340
# Epoch 417/500
# 83/83 - 6s - loss: 0.3058 - val_loss: 7.0319
#
# Epoch 00417: val_loss did not improve from 4.66340
# Epoch 418/500
# 83/83 - 6s - loss: 0.3077 - val_loss: 6.9661
#
# Epoch 00418: val_loss did not improve from 4.66340
# Epoch 419/500
# 83/83 - 6s - loss: 0.3030 - val_loss: 6.9990
#
# Epoch 00419: val_loss did not improve from 4.66340
# Epoch 420/500
# 83/83 - 6s - loss: 0.2631 - val_loss: 6.9872
#
# Epoch 00420: val_loss did not improve from 4.66340
# Epoch 421/500
# 83/83 - 6s - loss: 0.2294 - val_loss: 7.0083
#
# Epoch 00421: val_loss did not improve from 4.66340
# Epoch 422/500
# 83/83 - 6s - loss: 0.2123 - val_loss: 7.0077
#
# Epoch 00422: val_loss did not improve from 4.66340
# Epoch 423/500
# 83/83 - 6s - loss: 0.1911 - val_loss: 7.0265
#
# Epoch 00423: val_loss did not improve from 4.66340
# Epoch 424/500
# 83/83 - 6s - loss: 0.1785 - val_loss: 7.0241
#
# Epoch 00424: val_loss did not improve from 4.66340
# Epoch 425/500
# 83/83 - 6s - loss: 0.1683 - val_loss: 7.0233
#
# Epoch 00425: val_loss did not improve from 4.66340
# Epoch 426/500
# 83/83 - 6s - loss: 0.1599 - val_loss: 7.0320
#
# Epoch 00426: val_loss did not improve from 4.66340
# Epoch 427/500
# 83/83 - 6s - loss: 0.1552 - val_loss: 7.0304
#
# Epoch 00427: val_loss did not improve from 4.66340
# Epoch 428/500
# 83/83 - 6s - loss: 0.1522 - val_loss: 7.0351
#
# Epoch 00428: val_loss did not improve from 4.66340
# Epoch 429/500
# 83/83 - 6s - loss: 0.1515 - val_loss: 7.0352
#
# Epoch 00429: val_loss did not improve from 4.66340
# Epoch 430/500
# 83/83 - 6s - loss: 0.1528 - val_loss: 7.0350
#
# Epoch 00430: val_loss did not improve from 4.66340
# Epoch 431/500
# 83/83 - 6s - loss: 0.1540 - val_loss: 7.0554
#
# Epoch 00431: val_loss did not improve from 4.66340
# Epoch 432/500
# 83/83 - 6s - loss: 0.1581 - val_loss: 7.0425
#
# Epoch 00432: val_loss did not improve from 4.66340
# Epoch 433/500
# 83/83 - 6s - loss: 0.1652 - val_loss: 7.0760
#
# Epoch 00433: val_loss did not improve from 4.66340
# Epoch 434/500
# 83/83 - 6s - loss: 0.1794 - val_loss: 7.1222
#
# Epoch 00434: val_loss did not improve from 4.66340
# Epoch 435/500
# 83/83 - 6s - loss: 0.2253 - val_loss: 7.1119
#
# Epoch 00435: val_loss did not improve from 4.66340
# Epoch 436/500
# 83/83 - 6s - loss: 0.3413 - val_loss: 7.1152
#
# Epoch 00436: val_loss did not improve from 4.66340
# Epoch 437/500
# 83/83 - 6s - loss: 0.4205 - val_loss: 7.0720
#
# Epoch 00437: val_loss did not improve from 4.66340
# Epoch 438/500
# 83/83 - 6s - loss: 0.3549 - val_loss: 7.1157
#
# Epoch 00438: val_loss did not improve from 4.66340
# Epoch 439/500
# 83/83 - 6s - loss: 0.2786 - val_loss: 7.0585
#
# Epoch 00439: val_loss did not improve from 4.66340
# Epoch 440/500
# 83/83 - 6s - loss: 0.2163 - val_loss: 7.0746
#
# Epoch 00440: val_loss did not improve from 4.66340
# Epoch 441/500
# 83/83 - 6s - loss: 0.1816 - val_loss: 7.0417
#
# Epoch 00441: val_loss did not improve from 4.66340
# Epoch 442/500
# 83/83 - 6s - loss: 0.1596 - val_loss: 7.0428
#
# Epoch 00442: val_loss did not improve from 4.66340
# Epoch 443/500
# 83/83 - 6s - loss: 0.1459 - val_loss: 7.0609
#
# Epoch 00443: val_loss did not improve from 4.66340
# Epoch 444/500
# 83/83 - 6s - loss: 0.1376 - val_loss: 7.0666
#
# Epoch 00444: val_loss did not improve from 4.66340
# Epoch 445/500
# 83/83 - 6s - loss: 0.1358 - val_loss: 7.0762
#
# Epoch 00445: val_loss did not improve from 4.66340
# Epoch 446/500
# 83/83 - 6s - loss: 0.1402 - val_loss: 7.0794
#
# Epoch 00446: val_loss did not improve from 4.66340
# Epoch 447/500
# 83/83 - 6s - loss: 0.1386 - val_loss: 7.0821
#
# Epoch 00447: val_loss did not improve from 4.66340
# Epoch 448/500
# 83/83 - 6s - loss: 0.1382 - val_loss: 7.0881
#
# Epoch 00448: val_loss did not improve from 4.66340
# Epoch 449/500
# 83/83 - 6s - loss: 0.1403 - val_loss: 7.0745
#
# Epoch 00449: val_loss did not improve from 4.66340
# Epoch 450/500
# 83/83 - 6s - loss: 0.1459 - val_loss: 7.1078
#
# Epoch 00450: val_loss did not improve from 4.66340
# Epoch 451/500
# 83/83 - 6s - loss: 0.1667 - val_loss: 7.0932
#
# Epoch 00451: val_loss did not improve from 4.66340
# Epoch 452/500
# 83/83 - 6s - loss: 0.1890 - val_loss: 7.1091
#
# Epoch 00452: val_loss did not improve from 4.66340
# Epoch 453/500
# 83/83 - 6s - loss: 0.2130 - val_loss: 7.1017
#
# Epoch 00453: val_loss did not improve from 4.66340
# Epoch 454/500
# 83/83 - 6s - loss: 0.2453 - val_loss: 7.1936
#
# Epoch 00454: val_loss did not improve from 4.66340
# Epoch 455/500
# 83/83 - 6s - loss: 0.2479 - val_loss: 7.1368
#
# Epoch 00455: val_loss did not improve from 4.66340
# Epoch 456/500
# 83/83 - 6s - loss: 0.2284 - val_loss: 7.1383
#
# Epoch 00456: val_loss did not improve from 4.66340
# Epoch 457/500
# 83/83 - 6s - loss: 0.2015 - val_loss: 7.1502
#
# Epoch 00457: val_loss did not improve from 4.66340
# Epoch 458/500
# 83/83 - 6s - loss: 0.1685 - val_loss: 7.1245
#
# Epoch 00458: val_loss did not improve from 4.66340
# Epoch 459/500
# 83/83 - 6s - loss: 0.1529 - val_loss: 7.1539
#
# Epoch 00459: val_loss did not improve from 4.66340
# Epoch 460/500
# 83/83 - 6s - loss: 0.1460 - val_loss: 7.1680
#
# Epoch 00460: val_loss did not improve from 4.66340
# Epoch 461/500
# 83/83 - 6s - loss: 0.1376 - val_loss: 7.1434
#
# Epoch 00461: val_loss did not improve from 4.66340
# Epoch 462/500
# 83/83 - 6s - loss: 0.1307 - val_loss: 7.1498
#
# Epoch 00462: val_loss did not improve from 4.66340
# Epoch 463/500
# 83/83 - 6s - loss: 0.1241 - val_loss: 7.1423
#
# Epoch 00463: val_loss did not improve from 4.66340
# Epoch 464/500
# 83/83 - 6s - loss: 0.1197 - val_loss: 7.1474
#
# Epoch 00464: val_loss did not improve from 4.66340
# Epoch 465/500
# 83/83 - 6s - loss: 0.1162 - val_loss: 7.1638
#
# Epoch 00465: val_loss did not improve from 4.66340
# Epoch 466/500
# 83/83 - 6s - loss: 0.1155 - val_loss: 7.1616
#
# Epoch 00466: val_loss did not improve from 4.66340
# Epoch 467/500
# 83/83 - 6s - loss: 0.1150 - val_loss: 7.1656
#
# Epoch 00467: val_loss did not improve from 4.66340
# Epoch 468/500
# 83/83 - 6s - loss: 0.1167 - val_loss: 7.1656
#
# Epoch 00468: val_loss did not improve from 4.66340
# Epoch 469/500
# 83/83 - 6s - loss: 0.1218 - val_loss: 7.1799
#
# Epoch 00469: val_loss did not improve from 4.66340
# Epoch 470/500
# 83/83 - 6s - loss: 0.1344 - val_loss: 7.2073
#
# Epoch 00470: val_loss did not improve from 4.66340
# Epoch 471/500
# 83/83 - 6s - loss: 0.1741 - val_loss: 7.2127
#
# Epoch 00471: val_loss did not improve from 4.66340
# Epoch 472/500
# 83/83 - 6s - loss: 0.2618 - val_loss: 7.2181
#
# Epoch 00472: val_loss did not improve from 4.66340
# Epoch 473/500
# 83/83 - 6s - loss: 0.3457 - val_loss: 7.2247
#
# Epoch 00473: val_loss did not improve from 4.66340
# Epoch 474/500
# 83/83 - 6s - loss: 0.3606 - val_loss: 7.2130
#
# Epoch 00474: val_loss did not improve from 4.66340
# Epoch 475/500
# 83/83 - 6s - loss: 0.3075 - val_loss: 7.2249
#
# Epoch 00475: val_loss did not improve from 4.66340
# Epoch 476/500
# 83/83 - 6s - loss: 0.2214 - val_loss: 7.1720
#
# Epoch 00476: val_loss did not improve from 4.66340
# Epoch 477/500
# 83/83 - 6s - loss: 0.1626 - val_loss: 7.1866
#
# Epoch 00477: val_loss did not improve from 4.66340
# Epoch 478/500
# 83/83 - 6s - loss: 0.1312 - val_loss: 7.1932
#
# Epoch 00478: val_loss did not improve from 4.66340
# Epoch 479/500
# 83/83 - 6s - loss: 0.1163 - val_loss: 7.1871
#
# Epoch 00479: val_loss did not improve from 4.66340
# Epoch 480/500
# 83/83 - 6s - loss: 0.1079 - val_loss: 7.2008
#
# Epoch 00480: val_loss did not improve from 4.66340
# Epoch 481/500
# 83/83 - 6s - loss: 0.1024 - val_loss: 7.1941
#
# Epoch 00481: val_loss did not improve from 4.66340
# Epoch 482/500
# 83/83 - 6s - loss: 0.0992 - val_loss: 7.2052
#
# Epoch 00482: val_loss did not improve from 4.66340
# Epoch 483/500
# 83/83 - 6s - loss: 0.0970 - val_loss: 7.1989
#
# Epoch 00483: val_loss did not improve from 4.66340
# Epoch 484/500
# 83/83 - 6s - loss: 0.0965 - val_loss: 7.2164
#
# Epoch 00484: val_loss did not improve from 4.66340
# Epoch 485/500
# 83/83 - 6s - loss: 0.0970 - val_loss: 7.2222
#
# Epoch 00485: val_loss did not improve from 4.66340
# Epoch 486/500
# 83/83 - 6s - loss: 0.0981 - val_loss: 7.2340
#
# Epoch 00486: val_loss did not improve from 4.66340
# Epoch 487/500
# 83/83 - 6s - loss: 0.0986 - val_loss: 7.2159
#
# Epoch 00487: val_loss did not improve from 4.66340
# Epoch 488/500
# 83/83 - 6s - loss: 0.1016 - val_loss: 7.2368
#
# Epoch 00488: val_loss did not improve from 4.66340
# Epoch 489/500
# 83/83 - 6s - loss: 0.1076 - val_loss: 7.2461
#
# Epoch 00489: val_loss did not improve from 4.66340
# Epoch 490/500
# 83/83 - 6s - loss: 0.1237 - val_loss: 7.2481
#
# Epoch 00490: val_loss did not improve from 4.66340
# Epoch 491/500
# 83/83 - 6s - loss: 0.1802 - val_loss: 7.3353
#
# Epoch 00491: val_loss did not improve from 4.66340
# Epoch 492/500
# 83/83 - 6s - loss: 0.2537 - val_loss: 7.2417
#
# Epoch 00492: val_loss did not improve from 4.66340
# Epoch 493/500
# 83/83 - 6s - loss: 0.2580 - val_loss: 7.2655
#
# Epoch 00493: val_loss did not improve from 4.66340
# Epoch 494/500
# 83/83 - 6s - loss: 0.2381 - val_loss: 7.2656
#
# Epoch 00494: val_loss did not improve from 4.66340
# Epoch 495/500
# 83/83 - 6s - loss: 0.1932 - val_loss: 7.2806
#
# Epoch 00495: val_loss did not improve from 4.66340
# Epoch 496/500
# 83/83 - 6s - loss: 0.1536 - val_loss: 7.2537
#
# Epoch 00496: val_loss did not improve from 4.66340
# Epoch 497/500
# 83/83 - 6s - loss: 0.1295 - val_loss: 7.2870
#
# Epoch 00497: val_loss did not improve from 4.66340
# Epoch 498/500
# 83/83 - 6s - loss: 0.1160 - val_loss: 7.2731
#
# Epoch 00498: val_loss did not improve from 4.66340
# Epoch 499/500
# 83/83 - 6s - loss: 0.1057 - val_loss: 7.2656
#
# Epoch 00499: val_loss did not improve from 4.66340
# Epoch 500/500
# 83/83 - 6s - loss: 0.0984 - val_loss: 7.2466
#
# Epoch 00500: val_loss did not improve from 4.66340

# %%
loc = 'drive/MyDrive/nmt_test/'

# load datasets
dataset = load_clean_sentences(loc + 'english-nepali-both.pkl')
train = load_clean_sentences(loc + 'english-nepali-train.pkl')
test = load_clean_sentences(loc + 'english-nepali-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])

# prepare nepali tokenizer
nep_tokenizer = create_tokenizer(dataset[:, 1])
nep_vocab_size = len(nep_tokenizer.word_index) + 1
nep_length = max_length(dataset[:, 1])

# prepare data
trainX = encode_sequences(nep_tokenizer, nep_length, train[:, 1])
testX = encode_sequences(nep_tokenizer, nep_length, test[:, 1])

# %%
# load model
model = load_model('model.h5')

# %%
translation = model.predict(testX, verbose=0)

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# %%
# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# %%
# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
# 	print(raw_dataset[0])
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src = raw_dataset[i][0], raw_dataset[i][1]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# %%
# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[हामीलाई परोपकारी अर्थशास्त्रको जरुरत छ], target=[we need caring economics], predicted=[the the]
# src=[महामारी सम्बन्धी डाटाले पूर्वव्यापी ढङ्गमा sars को सूचक केसमा खेल पशुहरूसँग सम्पर्क इतिहास भएको कुरा खुलासा गर्‍यो।], target=[epidemiological data revealed retrospectively that the index case of sars had a contact history with game animals], predicted=[the the the the the the the]
# src=[उ मुर्मुरिदै आमाको बारेमा भन्दै थियो मैंले तिम्रो आमा बाहिर कुर्दै होला भंने ।], target=[he mumbled something about his mother and i told him shed probably find him outside anyway], predicted=[the the the the the the the]
# src=[औँलाका नङहरूको मुनि फोहोर भएमा यसलाई हटाउनका लागि ब्रिस्टल ब्रश प्रयोग गर्न सकिन्छ।], target=[if there is debris under fingernails a bristle brush may be used to remove it], predicted=[the the the the the the]
# src=[दर्शक मैले सम्भवत गर्न सक्छु होला अर्थर बेन्जामिन  म तपाईं संग पछि कुरा गरौँला ], target=[volunteer i can probably do it ab ill talk to you later], predicted=[the the the the the the]
# src=[उनीहरु आए र हामीलाई ऐना समेत कालो भएको कालो रंगको भ्यानमा लिएर गए उनीहरुले अनुहारमा मास्क लगाएका थिए ।], target=[they came they picked us up in a black van with black windows they were wearing masks on that day], predicted=[the the the the the the the the the]
# src=[दिलजान बजारकी महिला सहरानपुर  — । न्यूयोर्क पब्लिक लाइब्रेरीको डिजिटल संकलनबाट लिइएको तस्वीर।], target=[a hindu goldsmith sonar – photo from the new york public library digital collections hindu blacksmiths from madras –], predicted=[the the the the the the the the]
# src=[तेसैले आज यहाँ छु मेरो सुखी जीवनदर्शन सुनाउन], target=[so i’m here today to share with you my philosophy for a happy life], predicted=[the the the the the]
# src=[प्रिय मित्रहरू], target=[dear friends], predicted=[the]
# src=[विश्वभरि आशा र सामाजिक परिवर्तनको सन्देश फैलाउँदै नेपालका सेता पुतलीहरू], target=[these white butterflies from nepal are spreading a message of hope and social change throughout the world · global voices], predicted=[the the the the the the the]
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-1: 0.031293
# BLEU-2: 0.089161
# BLEU-3: 0.135540
# BLEU-4: 0.150501
# test
# src=[सरकारी क्षेत्रको ऋणात्मक बचत र लगानीको अन्तरलाई विदेशी सहायता र आन्तरिक ऋणबाट बेहोरिनेछ।], target=[the deficit between the public sector negative savings and investment will be borne thorough foreign assistance and internal borrowing], predicted=[the the the the the the the the the]
# src=[मृत्यु दर  बर्ष भन्दा माथिका लागि धेरै बढि तर  बर्ष भन्दा कमका लागि उल्लेखनीय रूपले कम छ।], target=[the fatality rate is much higher for those over  but significantly lower for those under ], predicted=[the the the the the the the]
# src=[उनी  बर्षदेखि यो समस्यामा छिन], target=[she has lived with crisis for  years], predicted=[the the the]
# src=[सिरियाली ब्लगर एस रिफाइ यस दोधारका बारे ट्वीट गर्छन्], target=[syrian blogger s rifai tweets about the confusion], predicted=[the the the the]
# src=[नेपालका पुराना फोटोहरूका लागि ट्वीटरमा नेपाल इन पिक्सलाई पछ्याउनुहोस्], target=[for stunning glimpses of thcentury nepal check out nepal in pix on twitter · global voices], predicted=[the the the the the the]
# src=[तर यो भयङ्कर ठुलो समस्या हो ।], target=[but that is a huge problem], predicted=[the the the]
# src=[त्यसपछि आफ्नो नातेदारहरुलाई सोध्ने प्रश्नहरुको सुची तयार पारेर अन्तर्वार्ताको समय मिलाउनुहुनेछ], target=[then maybe think about the questions you want to ask your relatives set up appointments to interview them], predicted=[the the the the the]
# src=[ऊनी साँच्चै निराश थिईन। अनि त्यो विद्यालयले सन को दशक तिर], target=[when she was at school she was really hopeless], predicted=[the the the the the]
# src=[साथै उत्पादनको आधार पनि परम्परागत नै रह्यो।], target=[in addition the mode of productiion continued to be traditional], predicted=[the the the the]
# src=[बस्तामा मैले आत्मामन को ससम्मान गरे र आत्माको कार्यलाई], target=[in fact i respect my self and its function], predicted=[the the the the]
# BLEU-1: 0.030298
# BLEU-2: 0.086331
# BLEU-3: 0.131241
# BLEU-4: 0.145728
